# %%
import pandas as pd
import numpy as np
from numpy.random import randn #To generate random numbers

# %%
my_data = randn(4, 3)
my_rows = ['A', 'B', 'C', 'D']
my_cols = ['Monday', 'Wednesday', 'Friday']

# %%
my_df = pd.DataFrame(my_data, my_rows, my_cols) #Creating the data frame
my_df
# Out:
#      Monday  Wednesday    Friday
# A  1.462900   0.507749  0.445124
# B -0.545127   0.907969  0.526195
# C  0.843162  -0.447357 -1.562528
# D  1.191958  -1.616110  0.699757

# %%
#Now importing a file from pc
my_df2 = pd.read_csv('California_Houses.csv')
my_df2
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0                452600.0         8.3252          41        880           129
# 1                358500.0         8.3014          21       7099          1106
# 2                352100.0         7.2574          52       1467           190
# 3                341300.0         5.6431          52       1274           235
# 4                342200.0         3.8462          52       1627           280
# ...                   ...            ...         ...        ...           ...
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
# ...

# %%
my_df2.loc[0] #Pulling a row from dataset
# Out:
# Median_House_Value          452600.000000
# Median_Income                    8.325200
# Median_Age                      41.000000
# Tot_Rooms                      880.000000
# Tot_Bedrooms                   129.000000
# Population                     322.000000
# Households                     126.000000
# Latitude                        37.880000
# Longitude                     -122.230000
# Distance_to_coast             9263.040773
# Distance_to_LA              556529.158342
# Distance_to_SanDiego        735501.806984
# Distance_to_SanJose          67432.517001
# Distance_to_SanFrancisco     21250.213767
# Name: 0, dtype: float64

# %%
my_df2.loc[[1,6]]  #Pulling multiple rows from dataset
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 1            358500.0         8.3014          21       7099          1106
# 6            299200.0         3.6591          52       2535           489
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 1        2401        1138     37.86    -122.22       10225.733072
# 6        1094         514     37.84    -122.25        6843.020847
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# 1   554279.850069         733236.884360         65049.908574
# 6   554364.406936         733249.808578         64315.991742
#
#    Distance_to_SanFrancisco
# 1              20880.600400
# 6              17538.209972

# %%
my_df2.head()  #Pulling first 5 rows
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# 2         496         177     37.85    -122.24        8259.085109
# 3         558         219     37.85    -122.25        7768.086571
# 4         565         259     37.85    -122.25        7768.086571
#
#    Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
my_df2.head(9) #To pull custom number of first rows
# Out:
#    Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 0            452600.0         8.3252          41        880           129
# 1            358500.0         8.3014          21       7099          1106
# 2            352100.0         7.2574          52       1467           190
# 3            341300.0         5.6431          52       1274           235
# 4            342200.0         3.8462          52       1627           280
# 5            269700.0         4.0368          52        919           213
# 6            299200.0         3.6591          52       2535           489
# 7            241400.0         3.1200          52       3104           687
# 8            226700.0         2.0804          42       2555           665
#
#    Population  Households  Latitude  Longitude  Distance_to_coast  \
# 0         322         126     37.88    -122.23        9263.040773
# 1        2401        1138     37.86    -122.22       10225.733072
# ...

# %%
my_df2.tail()  #Pull last 5 rows
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
#        Population  Households  Latitude  Longitude  Distance_to_coast  \
# 20635         845         330     39.48    -121.09      162031.481121
# 20636         356         114     39.49    -121.21      160445.433537
# 20637        1007         433     39.43    -121.22      153754.341182
# 20638         741         349     39.43    -121.32      152005.022239
# 20639        1387         530     39.37    -121.24      146866.196892
#
#        Distance_to_LA  Distance_to_SanDiego  Distance_to_SanJose  \
# ...

# %%
my_df2.tail(6)  #Pull custom numbers of last rows
# Out:
#        Median_House_Value  Median_Income  Median_Age  Tot_Rooms  Tot_Bedrooms  \
# 20634            116800.0         3.7125          28       2332           395
# 20635             78100.0         1.5603          25       1665           374
# 20636             77100.0         2.5568          18        697           150
# 20637             92300.0         1.7000          17       2254           485
# 20638             84700.0         1.8672          18       1860           409
# 20639             89400.0         2.3886          16       2785           616
#
#        Population  Households  Latitude  Longitude  Distance_to_coast  \
# 20634        1041         344     39.27    -121.56      132007.832093
# 20635         845         330     39.48    -121.09      162031.481121
# 20636         356         114     39.49    -121.21      160445.433537
# 20637        1007         433     39.43    -121.22      153754.341182
# 20638         741         349     39.43    -121.32      152005.022239
# ...

# %%
my_df2.info()  #Get info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Median_House_Value        20640 non-null  float64
#  1   Median_Income             20640 non-null  float64
#  2   Median_Age                20640 non-null  int64
#  3   Tot_Rooms                 20640 non-null  int64
#  4   Tot_Bedrooms              20640 non-null  int64
#  5   Population                20640 non-null  int64
#  6   Households                20640 non-null  int64
#  7   Latitude                  20640 non-null  float64
#  8   Longitude                 20640 non-null  float64
#  9   Distance_to_coast         20640 non-null  float64
#  10  Distance_to_LA            20640 non-null  float64
#  11  Distance_to_SanDiego      20640 non-null  float64
#  12  Distance_to_SanJose       20640 non-null  float64
# ...

# %%
my_df2.shape  #Getting shape of dataframe
# Out:
# (20640, 14)

# %%
my_df2.dtypes  #Get data type of dataframe members
# Out:
# Median_House_Value          float64
# Median_Income               float64
# Median_Age                    int64
# Tot_Rooms                     int64
# Tot_Bedrooms                  int64
# Population                    int64
# Households                    int64
# Latitude                    float64
# Longitude                   float64
# Distance_to_coast           float64
# Distance_to_LA              float64
# Distance_to_SanDiego        float64
# Distance_to_SanJose         float64
# Distance_to_SanFrancisco    float64
# dtype: object

# %%
my_df2['Median_Age'].describe()
# Out:
# count    20640.000000
# mean        28.639486
# std         12.585558
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: Median_Age, dtype: float64

# %%
my_df2['Median_Age']  #Pull a specific column
# Out:
# 0        41
# 1        21
# 2        52
# 3        52
# 4        52
#          ..
# 20635    25
# 20636    18
# 20637    17
# 20638    18
# 20639    16
# Name: Median_Age, Length: 20640, dtype: int64

# %%
my_df2.iloc[:, 0]  #Grab a specific column
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: Median_House_Value, Length: 20640, dtype: float64
